# %% [markdown]
# This notebook calculates the l^2-error between GraphSage and continuous version. It:
#     -read the graphs, graph signals, and positions via pickle from the local drive
#     -forwards
#     -forward the continuous version
#         -integration etc.
#     -calculated the l^2-error
#     -dumps it as a list
#     -plots and save the plot

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pickle #for saving and loading the dataset

import numpy as np
import networkx as nx
import torch
from torch_geometric.data import Data
import time


# In[2]:


import random
from torch_geometric.utils import from_networkx

import matplotlib.pyplot as plt

# In[13]:


# For plotting

# To avoid copying things to GPU memory,
# ideally allocate everything in torch on the GPU
# and avoid non-torch function calls
torch.set_printoptions(precision=10) # Set displayed output precision to 10 digits

from torchquad import enable_cuda # Necessary to enable GPU support
from torchquad import Trapezoid, Simpson, Boole, MonteCarlo, VEGAS # The available integrators
import torchquad


# In[3]:


from torch_geometric.nn import SAGEConv

enable_cuda() # Use this to enable GPU support
# Out:
# 08:23:01|TQ-INFO| Initializing torchquad.
# 08:23:01|TQ-INFO| __pyTorch VERSION:<module 'torch.version' from '/home/math/maskey/anaconda3/envs/pyg_cuda102/lib/python3.8/site-packages/torch/version.py'>
# 08:23:01|TQ-INFO| __CUDNN VERSION:7605
# 08:23:01|TQ-INFO| __Number of CUDA Devices:1
# 08:23:01|TQ-INFO| Active CUDA Device: GPU0
# 08:23:01|TQ-INFO| Setting default tensor type to cuda.Float32 (CUDA is initialized).

# %%
# In[4]:


N = 19702 #How large shall the graphs become?
skip = 100 #Should we consider all graphs, or only every skip'th
r = 0.2

#graphSage = SAGEConv(graphs[0].num_node_features,1 ,root_weight = False, bias = False)

RGG_data_set_values = []

# In[12]:


eucl_norm = lambda x,y: torch.sqrt(torch.pow(x,2) + torch.pow(y, 2))
def indicator_fct(x, y, distance, center):
    z = (eucl_norm(x-center[0], y- center[1]) < distance)*1
    return z

k = lambda x,y: x*y
g = lambda x,y, distance, center: indicator_fct(x, y, distance, center)*k(x,y)
#h = lambda x: g(x[:,0], x[:,1], 0.5, np.array(pos[50]))
#l = lambda x: indicator_fct(x[:,0],x[:,1], 0.5, np.array(pos[50]))


simp = Simpson()  # Initialize Simpson solver


def graph_l2error(gnn_output, position, length):
    error = 0
    for key, value in position.items():
        h = lambda x: g(x[:,0], x[:,1], r, torch.tensor(value))
        l = lambda x: indicator_fct(x[:,0],x[:,1], r, torch.tensor(value))
        int_of_f = simp.integrate(h,dim=2,N=1000000,integration_domain = [[0,1],[0,1]])
        measure_Ball = simp.integrate(l,dim=2,N=1000000,integration_domain = [[0,1],[0,1]])
        error2 = the_weight*(int_of_f/measure_Ball) - gnn_output[key]
        error = error + torch.pow(error2, 2)
    error = torch.sqrt( (1/length)*error )
    return error


l2_errors = []

with open('RGG_' + str(1) +'.pickle', 'rb') as data:
    graphs = pickle.load(data)
with open('graph_signal_' + str(1) +'.pickle', 'rb') as data:
    graph_signals = pickle.load(data)  
with open('pos_' + str(1) +'.pickle', 'rb') as data:
    pos = pickle.load(data)
RGG = Data(x = torch.tensor(graph_signals), edge_index = graphs.edge_index)
    
graphSage = SAGEConv(graphs.num_node_features,1 ,root_weight = False, bias = False)
 
start = time.time()    
    
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
graphSage = graphSage.to(device)
RGG = RGG.to(device)

end = time.time()
print(f"Took {(end-start)* 1000.0:.3f} ms -- " + str(1) + " nodes")    

start = time.time()

forward_value = graphSage.forward(RGG.x, RGG.edge_index)
    
end = time.time()
    
print(f"Took {(end-start)* 1000.0:.3f} ms -- " + str(1) + " nodes")    
    
the_weight = (graphSage.lin_l).weight
    
    
l2_errors.append(graph_l2error(forward_value, pos,1))
       

start = time.time ()


for j in range(101,N,skip):

    with open('RGG_' + str(j) +'.pickle', 'rb') as data:
        graphs = pickle.load(data)
    with open('graph_signal_' + str(j) +'.pickle', 'rb') as data:
        graph_signals = pickle.load(data)  
    with open('pos_' + str(j) +'.pickle', 'rb') as data:
        pos = pickle.load(data)
    RGG = Data(x = torch.tensor(graph_signals), edge_index = graphs.edge_index)
    
    RGG = RGG.to(device)
    
    forward_value = graphSage.forward(RGG.x, RGG.edge_index)
    
    #RGG_data_set_values.append(forward_value)
    
    l2_errors.append(graph_l2error(forward_value, pos, len(pos)))

    
end = time.time()
    
print(f"Took {(end-start)* 1000.0:.3f} ms -- " + str(101) + " nodes")    
    

hi = [tens.item() for tens in l2_errors]


he = list(range(0,len(l2_errors)))


fig = plt.figure()
plt.xlabel('Nodes')
plt.ylabel('l2error')
plt.plot(he,hi[:])
fig.savefig('l2error_' + str(N) + 'nodes_' + str(skip) + 'skip' + '.png', dpi=fig.dpi)


with open('l2_errors_' + str(N) + '.pickle', 'wb') as output:
    pickle.dump(l2_errors, output)
# Out:
# Took 0.594 ms -- 1 nodes
# /home/math/maskey/anaconda3/envs/pyg_cuda102/lib/python3.8/site-packages/torchquad/integration/simpson.py:101: UserWarning: N per dimension cannot be even due to necessary subdivisions. N per dim will now be changed to the next lower integer, i.e. 1000 -> 999.
#   warnings.warn(
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0047837608).
# 08:23:05|TQ-INFO| Integration grid created.
# Took 1457.784 ms -- 1 nodes
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0944750831).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0139202159).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1178835109).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0182205141).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1191403121).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0186928399).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1243689805).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0318407156).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256661713).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0216961317).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0798986107).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0285842791).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256518960).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0586674288).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1252406836).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0123467147).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256501079).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0089080520).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1065711975).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0295296274).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256434023).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0543034747).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256603599).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0099842828).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0917589962).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0010353588).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0668641925).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0062482897).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1217931435).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0116410311).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256634891).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0238342136).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256590337).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0276904553).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256545633).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0214444660).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1130818799).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0638609231).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256518960).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0081989467).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1240405589).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0198877119).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256710738).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0412802920).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1254140437).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0040770834).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0857749879).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0041797701).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0638116598).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0299329087).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256594658).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0064908587).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1192090288).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0154087469).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256688535).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0465110689).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1196664125).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0223865807).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1256639361).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0011735776).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0633600801).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.0102437679).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:05|TQ-INFO| Computed integral was tensor(0.1103349030).
# 08:23:05|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0627471432).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1198678911).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0265374295).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256630421).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0060488498).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0635092258).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0102436328).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256590188).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0489053056).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0680236071).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0807288066).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1214546710).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0170241427).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256478727).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0458459742).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256630421).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0352807678).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256599128).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0495392941).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0852200985).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0246062167).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0771487355).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0364525244).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0946475565).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0049775704).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0692297593).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0064684739).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1101195961).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0151099768).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0694644749).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0535385460).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256518960).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0354057364).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256799996).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0436806679).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0558314398).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0276494585).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256559044).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0289675035).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0797593892).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0140817743).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0646737739).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0200384744).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0905701444).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0637313724).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1064281762).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0575708784).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1020096391).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0379300490).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256777644).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0039073080).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0410039648).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0738661289).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1215751469).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0132393017).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256648302).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0223034639).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0643406659).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0559523478).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1195887700).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0189963765).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256639361).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0056618797).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0619191006).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0352460220).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1091751605).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0057616564).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0798588991).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0078963833).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1144127548).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.0191257782).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.1256804466).
# 08:23:06|TQ-INFO| Integration grid created.
# 08:23:06|TQ-INFO| Computed integral was tensor(0.

# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1012314186).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0078835245).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256648302).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0382951759).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256603599).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0158854350).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1245613024).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0187888145).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256808937).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0289611332).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256434023).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0483663268).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1023795605).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0108779501).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256844550).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0069823433).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0935145766).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0389740393).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0961629450).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0055594174).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1028173119).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0198770836).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0735967606).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0574377179).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1054408997).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0237074289).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256554574).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0183507055).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256733090).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0030699405).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0780853704).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0689648762).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1226884872).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0094962623).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0675440207).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0126327146).
# 08:23:07|TQ-INFO| Integration grid created.
# ...
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256639361).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0397242382).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0708772317).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0310387239).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1256666183).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0266804621).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.1181122065).
# 08:23:07|TQ-INFO| Integration grid created.
# 08:23:07|TQ-INFO| Computed integral was tensor(0.0135779940).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256639361).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0757698417).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1167677194).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0196884889).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256612539).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0141174719).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256777644).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0300641414).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256764382).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0566978827).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0758498758).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0199352354).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1239354834).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0204383042).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256965101).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0464055017).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0669098198).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0004040997).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0437676758).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0096303103).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0968735591).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0159273595).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1214009076).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0068701264).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256728619).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0620661154).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256750971).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0343899690).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1052537113).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0248288326).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0714994967).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0130394343).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0984608978).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0492052697).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0661852509).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0218404941).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256724149).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0515014380).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0708592683).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0059393696).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0973753408).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0292998459).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256420761).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0286049712).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256510019).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0524897613).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0902515352).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0175959319).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256693006).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0177883916).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256621480).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0107803447).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1078808755).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0731689036).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1106939018).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0140184741).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1197576672).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0749013498).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1175046712).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0290958565).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0940011889).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0128437374).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1069915444).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0077329138).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1199805588).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0025077397).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0987403467).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0728024542).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1152639315).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0192555189).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256514490).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0205088127).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256889105).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0043434603).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0897495374).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0600150377).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256559044).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0035682851).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0641407520).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0091652637).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0996905863).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0679469407).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256773174).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0160951819).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256791055).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0191025008).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256643832).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0205644090).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256679446).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0271726903).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256514490).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0407705158).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0515126288).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0505943336).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256541163).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0191010889).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256782115).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0195662808).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256657243).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0183962211).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1168558523).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0129369367).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1098018885).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0271015409).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0815770924).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0380360112).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256625950).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0662558675).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0936272517).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0029825033).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0776516348).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0243983082).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0781996027).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0352475196).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256563514).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0035753686).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1009667963).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0201924928).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256688535).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0575202890).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256603599).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0110736582).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0951927304).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0003976604).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0434454978).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0242660288).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256786585).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0397228189).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0500945151).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0049192328).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0496215150).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0526261143).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256545782).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0755745620).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1086033210).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0026353351).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0942392573).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0792803988).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1244325712).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0242048316).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.1256688535).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0032195486).
# 08:23:08|TQ-INFO| Integration grid created.
# 08:23:08|TQ-INFO| Computed integral was tensor(0.0735043958).
# Took 3063.195 ms -- 101 nodes

# %%
with open('RGG_' + str(11101) +'.pickle', 'rb') as data:
    graphs = pickle.load(data)
with open('graph_signal_' + str(1) +'.pickle', 'rb') as data:
    graph_signals = pickle.load(data)  
with open('pos_' + str(1) +'.pickle', 'rb') as data:
    pos = pickle.load(data)

# %%
graphs
# Out:
# Data(edge_index=[2, 12963728], pos=[11101, 2], num_nodes=11101)

# %%
he = list(range(0,N, skip))
fig = plt.figure()
plt.xlabel('Nodes')
plt.ylabel('l2error')
plt.plot(he,hi[:])
fig.savefig('l2error_' + str(N) + 'nodes_' + str(skip) + 'skip' + '.png', dpi=fig.dpi)

# %%
slope, intercept = np.polyfit(np.log(he[1:]), np.log(hi[1:]), 1)
print(slope)
plt.loglog(he[1:], hi[1:], '--')
fig.savefig('loglogerror_' + str(N) + 'nodes_' + str(skip) + 'skip' + '.png', dpi=fig.dpi)
# Out:
# -0.46583994477633633
