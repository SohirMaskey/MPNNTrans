# %% [markdown]
# This notebook
#     -reads the pickled files from the local disc
#     -makes a pytorch tensor object from it
#     -calculates a forward process for every graph and signal
#     -calculates the forward process for the continuous MLP with continuos signal
#
# It does not use cuda and is an old version and tested with only 1000 nodes with 100 skip

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pickle #for saving and loading the dataset

import numpy as np
import networkx as nx
import torch
from torch_geometric.data import Data
import time


# In[2]:


import random
from torch_geometric.utils import from_networkx

import matplotlib.pyplot as plt

# In[13]:


# For plotting

# To avoid copying things to GPU memory,
# ideally allocate everything in torch on the GPU
# and avoid non-torch function calls
torch.set_printoptions(precision=10) # Set displayed output precision to 10 digits

from torchquad import enable_cuda # Necessary to enable GPU support
from torchquad import Trapezoid, Simpson, Boole, MonteCarlo, VEGAS # The available integrators
import torchquad


# In[3]:


from torch_geometric.nn import SAGEConv


# In[4]:


N = 1002 #How large shall the graphs become?
skip = 100 #Should we consider all graphs, or only every skip'th
r = 0.2

#graphSage = SAGEConv(graphs[0].num_node_features,1 ,root_weight = False, bias = False)

RGG_data_set_values = []

# In[12]:


eucl_norm = lambda x,y: np.sqrt(x**2 + y**2)
def indicator_fct(x, y, distance, center):
    z = (eucl_norm(x-center[0], y- center[1]) < distance)*1
    return z

k = lambda x,y: x*y
g = lambda x,y, distance, center: indicator_fct(x, y, distance, center)*k(x,y)
#h = lambda x: g(x[:,0], x[:,1], 0.5, np.array(pos[50]))
#l = lambda x: indicator_fct(x[:,0],x[:,1], 0.5, np.array(pos[50]))


simp = Simpson()  # Initialize Simpson solver


def graph_l2error(gnn_output, position, length):
    error = 0
    for key, value in position.items():
        h = lambda x: g(x[:,0], x[:,1], r, np.array(value))
        l = lambda x: indicator_fct(x[:,0],x[:,1], r, np.array(value))
        int_of_f = simp.integrate(h,dim=2,N=1000000,integration_domain = [[0,1],[0,1]])
        measure_Ball = simp.integrate(l,dim=2,N=1000000,integration_domain = [[0,1],[0,1]])
        error2 = the_weight*(int_of_f/measure_Ball) - gnn_output[key]
        error = error + error2**2
    error = torch.sqrt( (1/length)*error )
    return error


l2_errors = []

with open('RGG_' + str(1) +'.pickle', 'rb') as data:
    graphs = pickle.load(data)
with open('graph_signal_' + str(1) +'.pickle', 'rb') as data:
    graph_signals = pickle.load(data)  
with open('pos_' + str(1) +'.pickle', 'rb') as data:
    pos = pickle.load(data)
RGG = Data(x = torch.tensor(graph_signals), edge_index = graphs.edge_index)
    
graphSage = SAGEConv(graphs.num_node_features,1 ,root_weight = False, bias = False)
    
forward_value = graphSage.forward(RGG.x, RGG.edge_index)
    
the_weight = (graphSage.lin_l).weight
    
    
l2_errors.append(graph_l2error(forward_value, pos,1))
       




for j in range(101,N,skip):
    with open('RGG_' + str(j) +'.pickle', 'rb') as data:
        graphs = pickle.load(data)
    with open('graph_signal_' + str(j) +'.pickle', 'rb') as data:
        graph_signals = pickle.load(data)  
    with open('pos_' + str(j) +'.pickle', 'rb') as data:
        pos = pickle.load(data)
    RGG = Data(x = torch.tensor(graph_signals), edge_index = graphs.edge_index)
    
    forward_value = graphSage.forward(RGG.x, RGG.edge_index)
    
    #RGG_data_set_values.append(forward_value)
    
    l2_errors.append(graph_l2error(forward_value, pos, len(pos)))


hi = [tens.item() for tens in l2_errors]


he = list(range(0,len(l2_errors)))


fig = plt.figure()
plt.xlabel('Nodes')
plt.ylabel('l2error')
plt.plot(he,hi[:])
fig.savefig('l2error_' + str(N) + 'nodes_' + str(skip) + 'skip' + '.png', dpi=fig.dpi

# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.1256737560).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0080855647).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0750714317).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0559897386).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0875105858).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0570372231).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.1256425232).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0052171531).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.1172942743).
# 13:17:23|TQ-INFO| Integration grid created.
# 13:17:23|TQ-INFO| Computed integral was tensor(0.0221311413).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1256447434).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0468914434).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0807839260).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0088473707).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0735955313).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0378457382).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0664631426).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0735323951).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1256608069).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0278663076).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1256585866).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0470693335).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1158685684).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0111913327).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1245061979).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0090505937).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0728237778).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0477846116).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1046396941).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0395822600).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1100412756).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0773561820).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1248250306).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0026926310).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1045540199).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0630660355).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0935681239).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0409220159).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1256590337).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.0734424368).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:24|TQ-INFO| Computed integral was tensor(0.1114120930).
# 13:17:24|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0428173691).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1256554574).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0206410568).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1256576926).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0126338480).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1219669431).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0701752305).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0995834917).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0465793349).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0608485937).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0072164414).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0649304613).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0748869479).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1253194511).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0677857921).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1135709435).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0177359637).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1169004664).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0219397992).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1202790886).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0132468408).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0760430917).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0080805849).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1032831594).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0248419102).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1256608069).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0590080507).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1215309948).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0071239443).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1151528209).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.0044597727).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:25|TQ-INFO| Computed integral was tensor(0.1003302559).
# 13:17:25|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0610902794).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256425083).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0267143752).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256514341).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0472580120).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0615351163).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0012428146).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0739810690).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0239647850).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256648302).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0065995832).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0757146776).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0048686420).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0997896492).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0405032113).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0996017829).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0070399810).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0913740247).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0746074915).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1106303036).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0212421902).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256804466).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0723587126).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256492138).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0756222457).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256599128).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0413750596).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256532371).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0217728522).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.1256773323).
# 13:17:26|TQ-INFO| Integration grid created.
# 13:17:26|TQ-INFO| Computed integral was tensor(0.0322626531).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0978005901).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0022650210).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0670374334).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0088130962).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1256715059).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0807931200).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1228861734).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0132256094).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0933553874).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0306606982).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1256581396).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0421786942).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1252567470).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0221283436).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0816199258).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0218119044).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0979317725).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0079201674).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0571926534).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0286605768).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1038206443).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0544745326).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1130394861).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0115625942).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1256661713).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0642386377).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1256724149).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0149613321).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.1179647297).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0209471695).
# 13:17:27|TQ-INFO| Integration grid created.
# 13:17:27|TQ-INFO| Computed integral was tensor(0.0956267938).
# 13:17:28|TQ-INFO| Integration grid created.
# 13:17:28|TQ-INFO| Computed integral was tensor(0.0204333384).
# 13:17:28|TQ-INFO| Integration grid created.
# 13:17:28|TQ-INFO| Computed integral was tensor(0.0666389614).
# 13:17:28|TQ-INFO| Integration grid created.
# 13:17:28|TQ-INFO| Computed integral was tensor(0.0034344350).
# 13:17:28|TQ-INFO| Integration grid created.
# 13:17:28|TQ-INFO| Computed integral was tensor(0.0671382844).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-04ab5851da95> in <module>
#     133 plt.ylabel('l2error')
#     134 plt.plot(he,hi[:])
# --> 135 fig.savefig('l2error_' + str(M) + 'nodes_' + str(skip) + 'skip' + '.png', dpi=fig.dpi)
#     136
#     137
#
# NameError: name 'M' is not defined

# %%
he = list(range(0,N, skip))

# %%
fig = plt.figure()
plt.xlabel('Nodes')
plt.ylabel('l2error')
plt.plot(he,hi[:])
fig.savefig('l2error_' + str(N) + 'nodes_' + str(skip) + 'skip' + '.png', dpi=fig.dpi)

# %%
plt.loglog(he,hi[:])

# %%
slope, intercept = np.polyfit(np.log(he[1:]), np.log(hi[1:]), 1)
print(slope)
plt.loglog(he[1:], hi[1:], '--')
plt.show()
# Out:
# -0.6919343848342694

# %%
hi
# Out:
# [0.040132954716682434,
#  0.02167349122464657,
#  0.01569267362356186,
#  0.011610248126089573,
#  0.009070849046111107,
#  0.007883941754698753,
#  0.006800617091357708,
#  0.006981915328651667,
#  0.005140273831784725,
#  0.004993479698896408,
#  0.004594363272190094]

# %%
he
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
