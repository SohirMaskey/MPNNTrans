# %%
import numpy as np
import networkx as nx
import torch
from torch_geometric.data import Data
import time

import random
from torch_geometric.utils import from_networkx

import matplotlib.pyplot as plt

from torch_geometric.nn import SAGEConv

from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree
import torch.nn.functional as F

import sys
sys.path.insert(1,'../src')
from DataLoader import RGGDataset
from TwoLayerGraphSage import GCN, cGCN

DL = RGGDataset(root = '//home/groups/ai/maskey/input')
# Out:
# 09:01:24|TQ-INFO| Initializing torchquad.

# %%
import pickle

# %%
model = GCN()
model.load_state_dict(torch.load( '../models/GCNTwoLayersGraphSage'))

cGCNN = cGCN()
model.load_state_dict(torch.load( '../models/cGCNTwoLayersGraphSage'))
# Out:
# <All keys matched successfully>

# %%
fct = lambda x: x[:,0]*x[:,1]
L2Errors = []
start = time.time()
for i in range(1, 302, 100):
    data = DL.get(i) 
    pos = data.pos
    #pos = pos.to(device)
    cfct = cGCNN.forward(fct)
        
    b = torch.empty(( 0 ))
    for i, w in enumerate(pos):
        b = torch.cat((b, cfct(w)), 0)
        #d = torch.reshape(b,(4, len(x)))
        
    #data = DL.get(i)
    #data = data.to(device)
    nodeErrors = b - model.forward(data)
    L2Error = torch.sqrt(1/len(nodeErrors)*torch.sum(torch.pow(nodeErrors,2)))
    L2Errors.append(L2Error)
end = time.time()
print(f"Took {(end-start)* 1000.0:.3f} ms")

# %%
err = [x.detach().numpy() for x in L2Errors]

# %%
xAxis = list(range(0,302, 100))
fig = plt.figure()
plt.xlabel('Nodes')
plt.ylabel('l2error')
plt.plot(xAxis,err[:])
#fig.savefig('../output/l2Error' + str(1002) + 'Nodes.png', dpi=fig.dpi)

# %%
slope, intercept = np.polyfit(np.log(xAxis[1:]), np.log(err[1:]), 1)
print(slope)
plt.loglog(xAxis[1:], err[1:], '--')
#fig.savefig('../output/Logl2Error' + str(1002) + 'Nodes.png', dpi=fig.dpi)

# %%
L2Errors

# %% [markdown]
# with open('../output/2LayerGraphSagel2Error1002Nodes.pickle', 'rb') as data:
#     l2_errors2 = pickle.load(data)

# %%
low_pass = lambda x: (1+(torch.tensor(x[:,0]**2 + x[:,1]**2))).pow_(-1)

# %%
fct = lambda x:  (1+(torch.tensor(x[:,0]**2 + x[:,1]**2))).pow_(-1)
L2Errors = []
start = time.time()
for i in range(1, 102, 100):
    data = DL.get(i) 
    pos = data.pos
    signal = low_pass(data.pos)
    signal = torch.reshape(signal,( len(signal),1))
    data.x = signal
    #pos = pos.to(device)
    cfct = cGCNN.forward(fct)
        
    b = torch.empty(( 0 ))
    for i, w in enumerate(pos):
        b = torch.cat((b, cfct(w)), 0)
        #d = torch.reshape(b,(4, len(x)))
        
    #data = DL.get(i)
    #data = data.to(device)
    nodeErrors = b - model.forward(data)
    L2Error = torch.sqrt(1/len(nodeErrors)*torch.sum(torch.pow(nodeErrors,2)))
    L2Errors.append(L2Error)
end = time.time()
print(f"Took {(end-start)* 1000.0:.3f} ms")
# Out:
# <ipython-input-4-e66a321be338>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   low_pass = lambda x: (1+(torch.tensor(x[:,0]**2 + x[:,1]**2))).pow_(-1)
# 09:04:40|TQ-INFO| Integration grid created.
# 09:04:41|TQ-INFO| Computed integral was tensor(-0.0183081739, grad_fn=<SumBackward1>).
# 09:04:41|TQ-INFO| Integration grid created.
# 09:04:41|TQ-INFO| Computed integral was tensor(0.0947753191).
# 09:04:41|TQ-INFO| Integration grid created.
# 09:04:42|TQ-INFO| Computed integral was tensor(-0.0270670876, grad_fn=<SumBackward1>).
# 09:04:42|TQ-INFO| Integration grid created.
# 09:04:42|TQ-INFO| Computed integral was tensor(0.1180989519).
# 09:04:42|TQ-INFO| Integration grid created.
# 09:04:43|TQ-INFO| Computed integral was tensor(-0.0289387852, grad_fn=<SumBackward1>).
# 09:04:43|TQ-INFO| Integration grid created.
# 09:04:43|TQ-INFO| Computed integral was tensor(0.1194178239).
# 09:04:43|TQ-INFO| Integration grid created.
# 09:04:43|TQ-INFO| Computed integral was tensor(-0.0298574157, grad_fn=<SumBackward1>).
# 09:04:43|TQ-INFO| Integration grid created.
# 09:04:43|TQ-INFO| Computed integral was tensor(0.1246934235).
# 09:04:43|TQ-INFO| Integration grid created.
# 09:04:44|TQ-INFO| Computed integral was tensor(-0.0289816707, grad_fn=<SumBackward1>).
# 09:04:44|TQ-INFO| Integration grid created.
# 09:04:44|TQ-INFO| Computed integral was tensor(0.1262436956).
# 09:04:44|TQ-INFO| Integration grid created.
# 09:04:45|TQ-INFO| Computed integral was tensor(-0.0202797335, grad_fn=<SumBackward1>).
# 09:04:45|TQ-INFO| Integration grid created.
# 09:04:45|TQ-INFO| Computed integral was tensor(0.0801749229).
# 09:04:45|TQ-INFO| Integration grid created.
# 09:04:46|TQ-INFO| Computed integral was tensor(-0.0285229143, grad_fn=<SumBackward1>).
# 09:04:46|TQ-INFO| Integration grid created.
# 09:04:46|TQ-INFO| Computed integral was tensor(0.1254107058).
# 09:04:46|TQ-INFO| Integration grid created.
# 09:04:46|TQ-INFO| Computed integral was tensor(-0.0319577456, grad_fn=<SumBackward1>).
# 09:04:46|TQ-INFO| Integration grid created.
# 09:04:46|TQ-INFO| Computed integral was tensor(0.1241380721).
# 09:04:46|TQ-INFO| Integration grid created.
# 09:04:47|TQ-INFO| Computed integral was tensor(-0.0257386863, grad_fn=<SumBackward1>).
# 09:04:47|TQ-INFO| Integration grid created.
# 09:04:47|TQ-INFO| Computed integral was tensor(0.1262899637).
# 09:04:47|TQ-INFO| Integration grid created.
# 09:04:48|TQ-INFO| Computed integral was tensor(-0.0225963406, grad_fn=<SumBackward1>).
# 09:04:48|TQ-INFO| Integration grid created.
# 09:04:48|TQ-INFO| Computed integral was tensor(0.1056967005).
# 09:04:48|TQ-INFO| Integration grid created.
# 09:04:48|TQ-INFO| Computed integral was tensor(-0.0290623438, grad_fn=<SumBackward1>).
# 09:04:48|TQ-INFO| Integration grid created.
# 09:04:48|TQ-INFO| Computed integral was tensor(0.1260585785).
# 09:04:49|TQ-INFO| Integration grid created.
# 09:04:49|TQ-INFO| Computed integral was tensor(-0.0315298252, grad_fn=<SumBackward1>).
# 09:04:49|TQ-INFO| Integration grid created.
# 09:04:49|TQ-INFO| Computed integral was tensor(0.1254569888).
# 09:04:49|TQ-INFO| Integration grid created.
# 09:04:50|TQ-INFO| Computed integral was tensor(-0.0222331993, grad_fn=<SumBackward1>).
# 09:04:50|TQ-INFO| Integration grid created.
# 09:04:50|TQ-INFO| Computed integral was tensor(0.0921953842).
# 09:04:50|TQ-INFO| Integration grid created.
# 09:04:51|TQ-INFO| Computed integral was tensor(-0.0113633787, grad_fn=<SumBackward1>).
# 09:04:51|TQ-INFO| Integration grid created.
# 09:04:51|TQ-INFO| Computed integral was tensor(0.0665116385).
# 09:04:51|TQ-INFO| Integration grid created.
# 09:04:51|TQ-INFO| Computed integral was tensor(-0.0225345120, grad_fn=<SumBackward1>).
# 09:04:51|TQ-INFO| Integration grid created.
# 09:04:51|TQ-INFO| Computed integral was tensor(0.1221713275).
# 09:04:51|TQ-INFO| Integration grid created.
# 09:04:52|TQ-INFO| Computed integral was tensor(-0.0252672564, grad_fn=<SumBackward1>).
# 09:04:52|TQ-INFO| Integration grid created.
# 09:04:52|TQ-INFO| Computed integral was tensor(0.1255958229).
# 09:04:52|TQ-INFO| Integration grid created.
# 09:04:53|TQ-INFO| Computed integral was tensor(-0.0298560765, grad_fn=<SumBackward1>).
# 09:04:53|TQ-INFO| Integration grid created.
# 09:04:53|TQ-INFO| Computed integral was tensor(0.1256420910).
# 09:04:53|TQ-INFO| Integration grid created.
# 09:04:54|TQ-INFO| Computed integral was tensor(-0.0279704668, grad_fn=<SumBackward1>).
# 09:04:54|TQ-INFO| Integration grid created.
# 09:04:54|TQ-INFO| Computed integral was tensor(0.1254569888).
# 09:04:54|TQ-INFO| Integration grid created.
# 09:04:54|TQ-INFO| Computed integral was tensor(-0.0279017575, grad_fn=<SumBackward1>).
# 09:04:54|TQ-INFO| Integration grid created.
# 09:04:54|TQ-INFO| Computed integral was tensor(0.1136332080).
# 09:04:54|TQ-INFO| Integration grid created.
# 09:04:55|TQ-INFO| Computed integral was tensor(-0.0327051282, grad_fn=<SumBackward1>).
# 09:04:55|TQ-INFO| Integration grid created.
# 09:04:55|TQ-INFO| Computed integral was tensor(0.1261974275).
# 09:04:55|TQ-INFO| Integration grid created.
# 09:04:56|TQ-INFO| Computed integral was tensor(-0.0236189291, grad_fn=<SumBackward1>).
# 09:04:56|TQ-INFO| Integration grid created.
# 09:04:56|TQ-INFO| Computed integral was tensor(0.1236984581).
# 09:04:56|TQ-INFO| Integration grid created.
# 09:04:56|TQ-INFO| Computed integral was tensor(-0.0264842790, grad_fn=<SumBackward1>).
# 09:04:56|TQ-INFO| Integration grid created.
# 09:04:56|TQ-INFO| Computed integral was tensor(0.1255032569).
# 09:04:57|TQ-INFO| Integration grid created.
# 09:04:57|TQ-INFO| Computed integral was tensor(-0.0312092323, grad_fn=<SumBackward1>).
# 09:04:57|TQ-INFO| Integration grid created.
# 09:04:57|TQ-INFO| Computed integral was tensor(0.1256420910).
# 09:04:57|TQ-INFO| Integration grid created.
# 09:04:58|TQ-INFO| Computed integral was tensor(-0.0165916197, grad_fn=<SumBackward1>).
# 09:04:58|TQ-INFO| Integration grid created.
# 09:04:58|TQ-INFO| Computed integral was tensor(0.0854505152).
# 09:04:58|TQ-INFO| Integration grid created.
# 09:04:59|TQ-INFO| Computed integral was tensor(-0.0149142062, grad_fn=<SumBackward1>).
# 09:04:59|TQ-INFO| Integration grid created.
# 09:04:59|TQ-INFO| Computed integral was tensor(0.0639548302).
# 09:04:59|TQ-INFO| Integration grid created.
# 09:04:59|TQ-INFO| Computed integral was tensor(-0.0288073029, grad_fn=<SumBackward1>).
# 09:04:59|TQ-INFO| Integration grid created.
# 09:04:59|TQ-INFO| Computed integral was tensor(0.1254107058).
# 09:04:59|TQ-INFO| Integration grid created.
# 09:05:00|TQ-INFO| Computed integral was tensor(-0.0222181492, grad_fn=<SumBackward1>).
# 09:05:00|TQ-INFO| Integration grid created.
# 09:05:00|TQ-INFO| Computed integral was tensor(0.1189782023).
# 09:05:00|TQ-INFO| Integration grid created.
# 09:05:01|TQ-INFO| Computed integral was tensor(-0.0255246870, grad_fn=<SumBackward1>).
# 09:05:01|TQ-INFO| Integration grid created.
# 09:05:01|TQ-INFO| Computed integral was tensor(0.1257809252).
# 09:05:01|TQ-INFO| Integration grid created.
# 09:05:02|TQ-INFO| Computed integral was tensor(-0.0303562861, grad_fn=<SumBackward1>).
# 09:05:02|TQ-INFO| Integration grid created.
# 09:05:02|TQ-INFO| Computed integral was tensor(0.1197880507).
# 09:05:02|TQ-INFO| Integration grid created.
# 09:05:02|TQ-INFO| Computed integral was tensor(-0.0289862528, grad_fn=<SumBackward1>).
# 09:05:02|TQ-INFO| Integration grid created.
# 09:05:02|TQ-INFO| Computed integral was tensor(0.1251330525).
# 09:05:02|TQ-INFO| Integration grid created.
# 09:05:03|TQ-INFO| Computed integral was tensor(-0.0110642519, grad_fn=<SumBackward1>).
# 09:05:03|TQ-INFO| Integration grid created.
# 09:05:03|TQ-INFO| Computed integral was tensor(0.0635383427).
# 09:05:03|TQ-INFO| Integration grid created.
# 09:05:04|TQ-INFO| Computed integral was tensor(-0.0240587089, grad_fn=<SumBackward1>).
# 09:05:04|TQ-INFO| Integration grid created.
# 09:05:04|TQ-INFO| Computed integral was tensor(0.1102086976).
# 09:05:04|TQ-INFO| Integration grid created.
# 09:05:05|TQ-INFO| Computed integral was tensor(-0.0314254686, grad_fn=<SumBackward1>).
# 09:05:05|TQ-INFO| Integration grid created.
# 09:05:05|TQ-INFO| Computed integral was tensor(0.1199731678).
# 09:05:05|TQ-INFO| Integration grid created.
# 09:05:05|TQ-INFO| Computed integral was tensor(-0.0279116668, grad_fn=<SumBackward1>).
# 09:05:05|TQ-INFO| Integration grid created.
# 09:05:05|TQ-INFO| Computed integral was tensor(0.1253644377).
# 09:05:05|TQ-INFO| Integration grid created.
# 09:05:06|TQ-INFO| Computed integral was tensor(-0.0155808441, grad_fn=<SumBackward1>).
# 09:05:06|TQ-INFO| Integration grid created.
# 09:05:06|TQ-INFO| Computed integral was tensor(0.0636887401).
# 09:05:06|TQ-INFO| Integration grid created.
# 09:05:07|TQ-INFO| Computed integral was tensor(-0.0241446849, grad_fn=<SumBackward1>).
# 09:05:07|TQ-INFO| Integration grid created.
# 09:05:07|TQ-INFO| Computed integral was tensor(0.1261048615).
# 09:05:07|TQ-INFO| Integration grid created.
# 09:05:07|TQ-INFO| Computed integral was tensor(-0.0187540539, grad_fn=<SumBackward1>).
# 09:05:07|TQ-INFO| Integration grid created.
# 09:05:07|TQ-INFO| Computed integral was tensor(0.0680272132).
# 09:05:07|TQ-INFO| Integration grid created.
# 09:05:08|TQ-INFO| Computed integral was tensor(-0.0331402719, grad_fn=<SumBackward1>).
# 09:05:08|TQ-INFO| Integration grid created.
# 09:05:08|TQ-INFO| Computed integral was tensor(0.1221019030).
# 09:05:08|TQ-INFO| Integration grid created.
# 09:05:09|TQ-INFO| Computed integral was tensor(-0.0259389710, grad_fn=<SumBackward1>).
# 09:05:09|TQ-INFO| Integration grid created.
# 09:05:09|TQ-INFO| Computed integral was tensor(0.1250404865).
# 09:05:09|TQ-INFO| Integration grid created.
# 09:05:10|TQ-INFO| Computed integral was tensor(-0.0305956881, grad_fn=<SumBackward1>).
# 09:05:10|TQ-INFO| Integration grid created.
# 09:05:10|TQ-INFO| Computed integral was tensor(0.1257346570).
# 09:05:10|TQ-INFO| Integration grid created.
# 09:05:10|TQ-INFO| Computed integral was tensor(-0.0293118041, grad_fn=<SumBackward1>).
# 09:05:10|TQ-INFO| Integration grid created.
# 09:05:10|TQ-INFO| Computed integral was tensor(0.1257346421).
# 09:05:10|TQ-INFO| Integration grid created.
# 09:05:11|TQ-INFO| Computed integral was tensor(-0.0228394512, grad_fn=<SumBackward1>).
# 09:05:11|TQ-INFO| Integration grid created.
# 09:05:11|TQ-INFO| Computed integral was tensor(0.0854042247).
# 09:05:11|TQ-INFO| Integration grid created.
# 09:05:12|TQ-INFO| Computed integral was tensor(-0.0196880400, grad_fn=<SumBackward1>).
# 09:05:12|TQ-INFO| Integration grid created.
# 09:05:12|TQ-INFO| Computed integral was tensor(0.0772363320).
# 09:05:12|TQ-INFO| Integration grid created.
# 09:05:12|TQ-INFO| Computed integral was tensor(-0.0242480952, grad_fn=<SumBackward1>).
# 09:05:12|TQ-INFO| Integration grid created.
# 09:05:12|TQ-INFO| Computed integral was tensor(0.0946364924).
# 09:05:13|TQ-INFO| Integration grid created.
# 09:05:13|TQ-INFO| Computed integral was tensor(-0.0162174813, grad_fn=<SumBackward1>).
# 09:05:13|TQ-INFO| Integration grid created.
# 09:05:13|TQ-INFO| Computed integral was tensor(0.0689758807).
# 09:05:13|TQ-INFO| Integration grid created.
# 09:05:14|TQ-INFO| Computed integral was tensor(-0.0212922152, grad_fn=<SumBackward1>).
# 09:05:14|TQ-INFO| Integration grid created.
# 09:05:14|TQ-INFO| Computed integral was tensor(0.1104400977).
# 09:05:14|TQ-INFO| Integration grid created.
# 09:05:15|TQ-INFO| Computed integral was tensor(-0.0175859109, grad_fn=<SumBackward1>).
# 09:05:15|TQ-INFO| Integration grid created.
# 09:05:15|TQ-INFO| Computed integral was tensor(0.0696931779).
# 09:05:15|TQ-INFO| Integration grid created.
# 09:05:15|TQ-INFO| Computed integral was tensor(-0.0316962376, grad_fn=<SumBackward1>).
# 09:05:15|TQ-INFO| Integration grid created.
# 09:05:15|TQ-INFO| Computed integral was tensor(0.1264750808).
# 09:05:15|TQ-INFO| Integration grid created.
# 09:05:16|TQ-INFO| Computed integral was tensor(-0.0307697952, grad_fn=<SumBackward1>).
# 09:05:16|TQ-INFO| Integration grid created.
# 09:05:16|TQ-INFO| Computed integral was tensor(0.1254107058).
# 09:05:16|TQ-INFO| Integration grid created.
# 09:05:17|TQ-INFO| Computed integral was tensor(-0.0155509273, grad_fn=<SumBackward1>).
# 09:05:17|TQ-INFO| Integration grid created.
# 09:05:17|TQ-INFO| Computed integral was tensor(0.0557059497).
# 09:05:17|TQ-INFO| Integration grid created.
# 09:05:18|TQ-INFO| Computed integral was tensor(-0.0302471686, grad_fn=<SumBackward1>).
# 09:05:18|TQ-INFO| Integration grid created.
# 09:05:18|TQ-INFO| Computed integral was tensor(0.1253181547).
# 09:05:18|TQ-INFO| Integration grid created.
# 09:05:18|TQ-INFO| Computed integral was tensor(-0.0205718428, grad_fn=<SumBackward1>).
# 09:05:18|TQ-INFO| Integration grid created.
# 09:05:18|TQ-INFO| Computed integral was tensor(0.0801749229).
# 09:05:18|TQ-INFO| Integration grid created.
# 09:05:19|TQ-INFO| Computed integral was tensor(-0.0163427833, grad_fn=<SumBackward1>).
# 09:05:19|TQ-INFO| Integration grid created.
# 09:05:19|TQ-INFO| Computed integral was tensor(0.0646489859).
# 09:05:19|TQ-INFO| Integration grid created.
# 09:05:20|TQ-INFO| Computed integral was tensor(-0.0226154067, grad_fn=<SumBackward1>).
# 09:05:20|TQ-INFO| Integration grid created.
# 09:05:20|TQ-INFO| Computed integral was tensor(0.0904715583).
# 09:05:20|TQ-INFO| Integration grid created.
# 09:05:20|TQ-INFO| Computed integral was tensor(-0.0284993798, grad_fn=<SumBackward1>).
# 09:05:20|TQ-INFO| Integration grid created.
# 09:05:20|TQ-INFO| Computed integral was tensor(0.1064833999).
# 09:05:20|TQ-INFO| Integration grid created.
# 09:05:21|TQ-INFO| Computed integral was tensor(-0.0271018725, grad_fn=<SumBackward1>).
# 09:05:21|TQ-INFO| Integration grid created.
# 09:05:21|TQ-INFO| Computed integral was tensor(0.1020176634).
# 09:05:21|TQ-INFO| Integration grid created.
# 09:05:22|TQ-INFO| Computed integral was tensor(-0.0294699129, grad_fn=<SumBackward1>).
# 09:05:22|TQ-INFO| Integration grid created.
# 09:05:22|TQ-INFO| Computed integral was tensor(0.1254107058).
# 09:05:22|TQ-INFO| Integration grid created.
# 09:05:23|TQ-INFO| Computed integral was tensor(-0.0103207761, grad_fn=<SumBackward1>).
# 09:05:23|TQ-INFO| Integration grid created.
# 09:05:23|TQ-INFO| Computed integral was tensor(0.0413600765).
# 09:05:23|TQ-INFO| Integration grid created.
# 09:05:23|TQ-INFO| Computed integral was tensor(-0.0326002128, grad_fn=<SumBackward1>).
# 09:05:23|TQ-INFO| Integration grid created.
# 09:05:23|TQ-INFO| Computed integral was tensor(0.1218473762).
# 09:05:23|TQ-INFO| Integration grid created.
# 09:05:24|TQ-INFO| Computed integral was tensor(-0.0259082913, grad_fn=<SumBackward1>).
# 09:05:24|TQ-INFO| Integration grid created.
# 09:05:24|TQ-INFO| Computed integral was tensor(0.1251330376).
# 09:05:24|TQ-INFO| Integration grid created.
# 09:05:25|TQ-INFO| Computed integral was tensor(-0.0164975375, grad_fn=<SumBackward1>).
# 09:05:25|TQ-INFO| Integration grid created.
# 09:05:25|TQ-INFO| Computed integral was tensor(0.0641399473).
# 09:05:25|TQ-INFO| Integration grid created.
# 09:05:25|TQ-INFO| Computed integral was tensor(-0.0308499783, grad_fn=<SumBackward1>).
# 09:05:25|TQ-INFO| Integration grid created.
# 09:05:26|TQ-INFO| Computed integral was tensor(0.1194409579).
# 09:05:26|TQ-INFO| Integration grid created.
# 09:05:26|TQ-INFO| Computed integral was tensor(-0.0273287296, grad_fn=<SumBackward1>).
# 09:05:26|TQ-INFO| Integration grid created.
# 09:05:26|TQ-INFO| Computed integral was tensor(0.1260585934).
# 09:05:26|TQ-INFO| Integration grid created.
# 09:05:27|TQ-INFO| Computed integral was tensor(-0.0150139416, grad_fn=<SumBackward1>).
# 09:05:27|TQ-INFO| Integration grid created.
# 09:05:27|TQ-INFO| Computed integral was tensor(0.0614443012).
# 09:05:27|TQ-INFO| Integration grid created.
# 09:05:28|TQ-INFO| Computed integral was tensor(-0.0274263341, grad_fn=<SumBackward1>).
# 09:05:28|TQ-INFO| Integration grid created.
# 09:05:28|TQ-INFO| Computed integral was tensor(0.1090286449).
# 09:05:28|TQ-INFO| Integration grid created.
# 09:05:28|TQ-INFO| Computed integral was tensor(-0.0178835578, grad_fn=<SumBackward1>).
# 09:05:28|TQ-INFO| Integration grid created.
# 09:05:28|TQ-INFO| Computed integral was tensor(0.0796196014).
# 09:05:28|TQ-INFO| Integration grid created.
# 09:05:29|TQ-INFO| Computed integral was tensor(-0.0225967672, grad_fn=<SumBackward1>).
# 09:05:29|TQ-INFO| Integration grid created.
# 09:05:29|TQ-INFO| Computed integral was tensor(0.1142116785).
# 09:05:29|TQ-INFO| Integration grid created.
# 09:05:30|TQ-INFO| Computed integral was tensor(-0.0262810383, grad_fn=<SumBackward1>).
# 09:05:30|TQ-INFO| Integration grid created.
# 09:05:30|TQ-INFO| Computed integral was tensor(0.1255032569).
# 09:05:30|TQ-INFO| Integration grid created.
# 09:05:31|TQ-INFO| Computed integral was tensor(-0.0277872756, grad_fn=<SumBackward1>).
# 09:05:31|TQ-INFO| Integration grid created.
# 09:05:31|TQ-INFO| Computed integral was tensor(0.1257346570).
# 09:05:31|TQ-INFO| Integration grid created.
# 09:05:31|TQ-INFO| Computed integral was tensor(-0.0193716381, grad_fn=<SumBackward1>).
# 09:05:31|TQ-INFO| Integration grid created.
# 09:05:31|TQ-INFO| Computed integral was tensor(0.0778263658).
# 09:05:31|TQ-INFO| Integration grid created.
# 09:05:32|TQ-INFO| Computed integral was tensor(-0.0160042923, grad_fn=<SumBackward1>).
# 09:05:32|TQ-INFO| Integration grid created.
# 09:05:32|TQ-INFO| Computed integral was tensor(0.0634457916).
# 09:05:32|TQ-INFO| Integration grid created.
# 09:05:33|TQ-INFO| Computed integral was tensor(-0.0326926373, grad_fn=<SumBackward1>).
# 09:05:33|TQ-INFO| Integration grid created.
# 09:05:33|TQ-INFO| Computed integral was tensor(0.1255958080).
# 09:05:33|TQ-INFO| Integration grid created.
# 09:05:34|TQ-INFO| Computed integral was tensor(-0.0223695375, grad_fn=<SumBackward1>).
# 09:05:34|TQ-INFO| Integration grid created.
# 09:05:34|TQ-INFO| Computed integral was tensor(0.1029432118).
# 09:05:34|TQ-INFO| Integration grid created.
# 09:05:34|TQ-INFO| Computed integral was tensor(-0.0137386154, grad_fn=<SumBackward1>).
# 09:05:34|TQ-INFO| Integration grid created.
# 09:05:34|TQ-INFO| Computed integral was tensor(0.0554282963).
# 09:05:34|TQ-INFO| Integration grid created.
# 09:05:35|TQ-INFO| Computed integral was tensor(-0.0281042941, grad_fn=<SumBackward1>).
# 09:05:35|TQ-INFO| Integration grid created.
# 09:05:35|TQ-INFO| Computed integral was tensor(0.1035216674).
# 09:05:35|TQ-INFO| Integration grid created.
# 09:05:36|TQ-INFO| Computed integral was tensor(-0.0321777798, grad_fn=<SumBackward1>).
# 09:05:36|TQ-INFO| Integration grid created.
# 09:05:36|TQ-INFO| Computed integral was tensor(0.1257809103).
# 09:05:36|TQ-INFO| Integration grid created.
# 09:05:36|TQ-INFO| Computed integral was tensor(-0.0148719307, grad_fn=<SumBackward1>).
# 09:05:36|TQ-INFO| Integration grid created.
# 09:05:36|TQ-INFO| Computed integral was tensor(0.0593155585).
# 09:05:36|TQ-INFO| Integration grid created.
# 09:05:37|TQ-INFO| Computed integral was tensor(-0.0308860801, grad_fn=<SumBackward1>).
# 09:05:37|TQ-INFO| Integration grid created.
# 09:05:37|TQ-INFO| Computed integral was tensor(0.1192558631).
# 09:05:37|TQ-INFO| Integration grid created.
# 09:05:38|TQ-INFO| Computed integral was tensor(-0.0311021823, grad_fn=<SumBackward1>).
# 09:05:38|TQ-INFO| Integration grid created.
# 09:05:38|TQ-INFO| Computed integral was tensor(0.1257809103).
# 09:05:38|TQ-INFO| Integration grid created.
# 09:05:39|TQ-INFO| Computed integral was tensor(-0.0254420899, grad_fn=<SumBackward1>).
# 09:05:39|TQ-INFO| Integration grid created.
# 09:05:39|TQ-INFO| Computed integral was tensor(0.1005368084).
# 09:05:39|TQ-INFO| Integration grid created.
# 09:05:39|TQ-INFO| Computed integral was tensor(-0.0237346031, grad_fn=<SumBackward1>).
# 09:05:39|TQ-INFO| Integration grid created.
# 09:05:39|TQ-INFO| Computed integral was tensor(0.1251793206).
# 09:05:39|TQ-INFO| Integration grid created.
# 09:05:40|TQ-INFO| Computed integral was tensor(-0.0267998241, grad_fn=<SumBackward1>).
# 09:05:40|TQ-INFO| Integration grid created.
# 09:05:40|TQ-INFO| Computed integral was tensor(0.1004442498).
# 09:05:40|TQ-INFO| Integration grid created.
# 09:05:41|TQ-INFO| Computed integral was tensor(-0.0172534678, grad_fn=<SumBackward1>).
# 09:05:41|TQ-INFO| Integration grid created.
# 09:05:41|TQ-INFO| Computed integral was tensor(0.0666620359).
# 09:05:41|TQ-INFO| Integration grid created.
# 09:05:41|TQ-INFO| Computed integral was tensor(-0.0319257341, grad_fn=<SumBackward1>).
# 09:05:41|TQ-INFO| Integration grid created.
# 09:05:41|TQ-INFO| Computed integral was tensor(0.1257346421).
# 09:05:41|TQ-INFO| Integration grid created.
# 09:05:42|TQ-INFO| Computed integral was tensor(-0.0245401170, grad_fn=<SumBackward1>).
# 09:05:42|TQ-INFO| Integration grid created.
# 09:05:42|TQ-INFO| Computed integral was tensor(0.0890485421).
# 09:05:42|TQ-INFO| Integration grid created.
# 09:05:43|TQ-INFO| Computed integral was tensor(-0.0284932908, grad_fn=<SumBackward1>).
# 09:05:43|TQ-INFO| Integration grid created.
# 09:05:43|TQ-INFO| Computed integral was tensor(0.1254569739).
# 09:05:43|TQ-INFO| Integration grid created.
# 09:05:44|TQ-INFO| Computed integral was tensor(-0.0295127220, grad_fn=<SumBackward1>).
# 09:05:44|TQ-INFO| Integration grid created.
# 09:05:44|TQ-INFO| Computed integral was tensor(0.1084733158).
# 09:05:44|TQ-INFO| Integration grid created.
# 09:05:44|TQ-INFO| Computed integral was tensor(-0.0320108272, grad_fn=<SumBackward1>).
# 09:05:44|TQ-INFO| Integration grid created.
# 09:05:44|TQ-INFO| Computed integral was tensor(0.1249479204).
# 09:05:44|TQ-INFO| Integration grid created.
# 09:05:45|TQ-INFO| Computed integral was tensor(-0.0313357376, grad_fn=<SumBackward1>).
# 09:05:45|TQ-INFO| Integration grid created.
# 09:05:45|TQ-INFO| Computed integral was tensor(0.1251793057).
# 09:05:45|TQ-INFO| Integration grid created.
# 09:05:46|TQ-INFO| Computed integral was tensor(-0.0332588442, grad_fn=<SumBackward1>).
# 09:05:46|TQ-INFO| Integration grid created.
# 09:05:46|TQ-INFO| Computed integral was tensor(0.1240918040).
# 09:05:46|TQ-INFO| Integration grid created.
# 09:05:47|TQ-INFO| Computed integral was tensor(-0.0254774429, grad_fn=<SumBackward1>).
# 09:05:47|TQ-INFO| Integration grid created.
# 09:05:47|TQ-INFO| Computed integral was tensor(0.1252256036).
# 09:05:47|TQ-INFO| Integration grid created.
# 09:05:47|TQ-INFO| Computed integral was tensor(-0.0289229564, grad_fn=<SumBackward1>).
# 09:05:47|TQ-INFO| Integration grid created.
# 09:05:47|TQ-INFO| Computed integral was tensor(0.1252718866).
# 09:05:47|TQ-INFO| Integration grid created.
# 09:05:48|TQ-INFO| Computed integral was tensor(-0.0217994098, grad_fn=<SumBackward1>).
# 09:05:48|TQ-INFO| Integration grid created.
# 09:05:48|TQ-INFO| Computed integral was tensor(0.0835300088).
# 09:05:48|TQ-INFO| Integration grid created.
# 09:05:49|TQ-INFO| Computed integral was tensor(-0.0200652555, grad_fn=<SumBackward1>).
# 09:05:49|TQ-INFO| Integration grid created.
# 09:05:49|TQ-INFO| Computed integral was tensor(0.0782544240).
# 09:05:49|TQ-INFO| Integration grid created.
# 09:05:49|TQ-INFO| Computed integral was tensor(-0.0282976273, grad_fn=<SumBackward1>).
# 09:05:49|TQ-INFO| Integration grid created.
# 09:05:49|TQ-INFO| Computed integral was tensor(0.1257346421).
# 09:05:49|TQ-INFO| Integration grid created.
# 09:05:50|TQ-INFO| Computed integral was tensor(-0.0092925932, grad_fn=<SumBackward1>).
# 09:05:50|TQ-INFO| Integration grid created.
# 09:05:50|TQ-INFO| Computed integral was tensor(0.0548729710).
# 09:05:50|TQ-INFO| Integration grid created.
# 09:05:51|TQ-INFO| Computed integral was tensor(-0.0300996527, grad_fn=<SumBackward1>).
# 09:05:51|TQ-INFO| Integration grid created.
# 09:05:51|TQ-INFO| Computed integral was tensor(0.1255032718).
# 09:05:51|TQ-INFO| Integration grid created.
# 09:05:52|TQ-INFO| Computed integral was tensor(-0.0144376401, grad_fn=<SumBackward1>).
# 09:05:52|TQ-INFO| Integration grid created.
# 09:05:52|TQ-INFO| Computed integral was tensor(0.0837266743).
# 09:05:52|TQ-INFO| Integration grid created.
# 09:05:52|TQ-INFO| Computed integral was tensor(-0.0209180769, grad_fn=<SumBackward1>).
# 09:05:52|TQ-INFO| Integration grid created.
# 09:05:52|TQ-INFO| Computed integral was tensor(0.0950992629).
# 09:05:52|TQ-INFO| Integration grid created.
# 09:05:53|TQ-INFO| Computed integral was tensor(-0.0292471871, grad_fn=<SumBackward1>).
# 09:05:53|TQ-INFO| Integration grid created.
# 09:05:53|TQ-INFO| Computed integral was tensor(0.1250867695).
# 09:05:53|TQ-INFO| Integration grid created.
# 09:05:54|TQ-INFO| Computed integral was tensor(-0.0327438749, grad_fn=<SumBackward1>).
# 09:05:54|TQ-INFO| Integration grid created.
# 09:05:54|TQ-INFO| Computed integral was tensor(0.1251330376).
# 09:05:54|TQ-INFO| Integration grid created.
# 09:05:55|TQ-INFO| Computed integral was tensor(-0.0243164580, grad_fn=<SumBackward1>).
# 09:05:55|TQ-INFO| Integration grid created.
# 09:05:55|TQ-INFO| Computed integral was tensor(0.0977601930).
# Took 74114.640 ms

# %%
err = [x.detach().numpy() for x in L2Errors]
xAxis = list(range(0,102, 100))
fig = plt.figure()
plt.xlabel('Nodes')
plt.ylabel('l2error')
plt.plot(xAxis,err[:])
#fig.savefig('../output/l2Error' + str(1002) + 'Nodes.png', dpi=fig.dpi)
