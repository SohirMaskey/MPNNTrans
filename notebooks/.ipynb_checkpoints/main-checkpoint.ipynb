# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pickle #for saving and loading the dataset

import numpy as np
import networkx as nx
import torch
from torch_geometric.data import Data
import time


# In[2]:


import random
from torch_geometric.utils import from_networkx

import matplotlib.pyplot as plt

# In[13]:


# For plotting

# To avoid copying things to GPU memory,
# ideally allocate everything in torch on the GPU
# and avoid non-torch function calls
"""
torch.set_printoptions(precision=10) # Set displayed output precision to 10 digits

from torchquad import enable_cuda # Necessary to enable GPU support
from torchquad import Trapezoid, Simpson, Boole, MonteCarlo, VEGAS # The available integrators
import torchquad


"""

# In[3]:


from torch_geometric.nn import SAGEConv

#enable_cuda() # Use this to enable GPU support

# %%
import sys
sys.path.insert(1,'../src')
from DataLoader import RGGDataset

# %%
DL = RGGDataset(root = "../input", size = 302)

# %%
model = torch.load("../models/graphSageOneLayer.pt")

# %%
from CGraphSage import forward
# Out:
# 15:47:13|TQ-INFO| Initializing torchquad.
# 15:47:13|TQ-INFO| __pyTorch VERSION:<module 'torch.version' from '/home/math/maskey/anaconda3/envs/pyg_cuda102/lib/python3.8/site-packages/torch/version.py'>
# 15:47:13|TQ-INFO| __CUDNN VERSION:7605
# 15:47:13|TQ-INFO| __Number of CUDA Devices:1
# 15:47:13|TQ-INFO| Active CUDA Device: GPU0
# 15:47:13|TQ-INFO| Setting default tensor type to cuda.Float32 (CUDA is initialized).

# %%
the_weight = (model.lin_l).weight
pos = DL.get(101).pos
data = DL.get(101)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
data = data.to(device)

# %%
o = forward(positions = pos, weight = the_weight)
# Out:
# /home/math/maskey/anaconda3/envs/pyg_cuda102/lib/python3.8/site-packages/torchquad/integration/simpson.py:101: UserWarning: N per dimension cannot be even due to necessary subdivisions. N per dim will now be changed to the next lower integer, i.e. 1000 -> 999.
#   warnings.warn(
# 15:47:20|TQ-INFO| Integration grid created.
# 15:47:20|TQ-INFO| Computed integral was tensor(0.0139202159).
# 15:47:20|TQ-INFO| Integration grid created.
# 15:47:20|TQ-INFO| Computed integral was tensor(0.1178835109).
# /home/math/maskey/Dokumente/Project_Transferability_MPNN/python_scripts/notebooks/../src/CGraphSage.py:60: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   values.append([torch.tensor(the_weight*(int_of_f/measure_Ball))])
# 15:47:20|TQ-INFO| Integration grid created.
# 15:47:20|TQ-INFO| Computed integral was tensor(0.0182205141).
# ...

# %%
u = model.forward(data.x, data.edge_index)

# %%
print(o[:10], u[:10], (o-u)[:10])
# Out:
# tensor([[0.0534723438],
#         [0.0692529380],
#         [0.0680611879],
#         [0.1147362664],
#         [0.1229643971],
#         [0.1030135825],
#         [0.2121230811],
#         [0.0444963984],
#         [0.0378511623],
#         [0.1064276770]]) tensor([[0.0513171963],
#         [0.0734363273],
#         [0.0612256899],
#         [0.1120392531],
#         [0.1145285442],
#         [0.0991532356],
#         [0.2325192094],
#         [0.0516068004],
#         [0.0324611254],
#         [0.1128768325]], grad_fn=<SliceBackward>) tensor([[ 0.0021551475],
#         [-0.0041833892],
#         [ 0.0068354979],
#         [ 0.0026970133],
#         [ 0.0084358528],
#         [ 0.0038603470],
#         [-0.0203961283],
#         [-0.0071104020],
#         [ 0.0053900369],
#         [-0.0064491555]], grad_fn=<SliceBackward>)

# %%
o[0] - u[0]
# Out:
# tensor([0.0021551475], grad_fn=<SubBackward0>)

# %%
error = the_weight*(forward(positions = pos, weight = the_weight)) - model.forward(data.x, data.edge_index)

# %%
error

# %%
error = 0
for i in range(1, 302, 100):
    pos = DL.get(i).pos
    cOutput = forward(positions = pos, weight = the_weight)
    data = DL.get(i)
    data = data.to(device)
    node_error = the_weight*(cOutput[i] - model.forward(data.x, data.edge_index))
    error = error + 
    error2 = the_weight*(int_of_f/measure_Ball) - gnn_output[key]
    error = error + torch.pow(error2, 2)
    error = torch.sqrt( (1/length)*error )

# %%
a = torch.tensor(7)

# %%
d = torch.tensor(8)

# %%
b = [[a], [d]]

# %%
c = torch.tensor(b)

# %%
c

# %%
hi = []

# %%
hi.append([a])

# %%
hi.append([d])

# %%
he = torch.tensor(hi)

# %%
he
